# %%
import numpy as np
import json
import matplotlib.pyplot as plt

# %%
data_path = '/content/drive/MyDrive/mimic-iii-clinical-database-1.4/embeddings/data.json'
data = []
with open(data_path, 'r') as f:
    for line in f:
        data.append(json.loads(line))

label_path = '/content/drive/MyDrive/mimic-iii-clinical-database-1.4/embeddings/target_jm.json'
labels = []        
with open(label_path, 'r') as f:
    for line in f:
        labels.append(json.loads(line))

# %%
label = []
corr_data = []
for i in range(len(data)):
  key = list(data[i].keys())[0]
  label.append(labels[i][key])
  corr_data.append(data[i][key])

# %%
corr_data = np.array(corr_data)
new_data = corr_data[:,2:,:]
new_data.shape
# Out:
# (10004, 10, 768)

# %%
corr_data = new_data

# %%
num_patients = len(corr_data)
num_features = len(corr_data[0])
embedding_size = len(corr_data[0][0])
print(num_patients)
print(num_features)
print(embedding_size)
# Out:
# 10004
# 10
# 768

# %%
tabular_data = np.array(corr_data).reshape(num_patients, -1)
tabular_data.shape
# Out:
# (10004, 7680)

# %%
label = np.array(label)
label_counts =np.unique(label, return_counts=True)
num_ones = np.count_nonzero(label)
num_zeroes = len(label) - num_ones
print("Survived:", num_zeroes)
print("Died:", num_ones)
print(f'Ratio(Died/Survived) = {num_ones/num_zeroes}')
# Out:
# Survived: 8727
# Died: 1277
# Ratio(Died/Survived) = 0.14632748940071044

# %%
# !pip install pytorch-tabnet -q

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
class LDAMLoss(nn.Module):

    def __init__(self, cls_num_list, max_m=0.5, weight=None, s=30):
        super(LDAMLoss, self).__init__()
        m_list = 1.0 / np.sqrt(np.sqrt(cls_num_list))
        m_list = m_list * (max_m / np.max(m_list))
        m_list = torch.cuda.FloatTensor(m_list)
        self.m_list = m_list
        assert s > 0
        self.s = s
        self.weight = weight

    def forward(self, x, target):
        index = torch.zeros_like(x, dtype=torch.uint8)
        index.scatter_(1, target.data.view(-1, 1), 1)

        index_float = index.type(torch.cuda.FloatTensor)
        batch_m = torch.matmul(self.m_list[None, :], index_float.transpose(0,1))
        batch_m = batch_m.view((-1, 1))
        x_m = x - batch_m

        output = torch.where(index, x_m, x)
        return F.cross_entropy(self.s*output, target, weight=self.weight)

# %%
torch.tensor((num_ones, num_zeroes))/1e4
# Out:
# tensor([0.1277, 0.8727])

# %%
from pytorch_tabnet.tab_model import TabNetClassifier
max_epochs = 1000

from sklearn.model_selection import train_test_split

# Splitting data into training and testing sets (70% train, 30% test)
X_train_val, X_test, y_train_val, y_test = train_test_split(tabular_data, label, test_size=0.15, random_state=42)

# Splitting training and validation sets from the remaining data (70% train, 15% validation)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.18, random_state=42)

y_train_int = y_train.astype(int)
cls_num_list = np.bincount(y_train_int)

loss_fn = nn.CrossEntropyLoss(weight=torch.tensor((num_ones, num_zeroes)).to('cuda')/1e4)

clf = TabNetClassifier(n_d=50, n_a=50, n_steps=10, n_independent=5, n_shared=5, device_name = 'cuda')
save_history = []

# Fit the model
clf.fit(
    X_train=X_train,
    y_train=y_train,
    eval_set=[(X_train,y_train), (X_val, y_val)],
    eval_name=['train','valid'],
    max_epochs=max_epochs,
    eval_metric=['balanced_accuracy', 'auc'],
    loss_fn = loss_fn,
    patience = 0
)
save_history.append(clf.history["valid_balanced_accuracy"])
# Out:
# /opt/conda/lib/python3.10/site-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cuda
#   warnings.warn(f"Device used : {self.device}")
# /opt/conda/lib/python3.10/site-packages/pytorch_tabnet/abstract_model.py:687: UserWarning: No early stopping will be performed, last training weights will be used.
#   warnings.warn(wrn_msg)
# epoch 0  | loss: 1.72685 | train_balanced_accuracy: 0.50181 | train_auc: 0.50278 | valid_balanced_accuracy: 0.49585 | valid_auc: 0.50047 |  0:00:08s
# epoch 1  | loss: 1.69148 | train_balanced_accuracy: 0.5     | train_auc: 0.57713 | valid_balanced_accuracy: 0.5     | valid_auc: 0.54518 |  0:00:15s
# epoch 2  | loss: 1.54697 | train_balanced_accuracy: 0.49975 | train_auc: 0.51319 | valid_balanced_accuracy: 0.49925 | valid_auc: 0.50324 |  0:00:22s
# epoch 3  | loss: 1.43353 | train_balanced_accuracy: 0.49873 | train_auc: 0.44768 | valid_balanced_accuracy: 0.49641 | valid_auc: 0.44116 |  0:00:29s
# epoch 4  | loss: 1.31639 | train_balanced_accuracy: 0.51107 | train_auc: 0.53752 | valid_balanced_accuracy: 0.49294 | valid_auc: 0.53332 |  0:00:36s
# epoch 5  | loss: 1.17386 | train_balanced_accuracy: 0.50028 | train_auc: 0.4536  | valid_balanced_accuracy: 0.49791 | valid_auc: 0.48292 |  0:00:43s
# epoch 6  | loss: 0.98071 | train_balanced_accuracy: 0.52896 | train_auc: 0.53003 | valid_balanced_accuracy: 0.49974 | valid_auc: 0.50156 |  0:00:50s
# epoch 7  | loss: 0.85122 | train_balanced_accuracy: 0.5     | train_auc: 0.55734 | valid_balanced_accuracy: 0.5     | valid_auc: 0.55694 |  0:00:58s
# epoch 8  | loss: 0.92558 | train_balanced_accuracy: 0.50008 | train_auc: 0.55434 | valid_balanced_accuracy: 0.5     | valid_auc: 0.53059 |  0:01:05s
# epoch 9  | loss: 0.90373 | train_balanced_accuracy: 0.5     | train_auc: 0.60308 | valid_balanced_accuracy: 0.5     | valid_auc: 0.58501 |  0:01:11s
# epoch 10 | loss: 1.0282  | train_balanced_accuracy: 0.5     | train_auc: 0.60252 | valid_balanced_accuracy: 0.5     | valid_auc: 0.57365 |  0:01:18s
# epoch 11 | loss: 0.96669 | train_balanced_accuracy: 0.50294 | train_auc: 0.53416 | valid_balanced_accuracy: 0.50173 | valid_auc: 0.50956 |  0:01:25s
# epoch 12 | loss: 0.76809 | train_balanced_accuracy: 0.50233 | train_auc: 0.58056 | valid_balanced_accuracy: 0.50473 | valid_auc: 0.57976 |  0:01:32s
# epoch 13 | loss: 0.73645 | train_balanced_accuracy: 0.51826 | train_auc: 0.52862 | valid_balanced_accuracy: 0.52553 | valid_auc: 0.55889 |  0:01:39s
# epoch 14 | loss: 0.69498 | train_balanced_accuracy: 0.5     | train_auc: 0.61486 | valid_balanced_accuracy: 0.5     | valid_auc: 0.60996 |  0:01:46s
# epoch 15 | loss: 1.02732 | train_balanced_accuracy: 0.5     | train_auc: 0.56654 | valid_balanced_accuracy: 0.5     | valid_auc: 0.56502 |  0:01:53s
# epoch 139| loss: 0.62166 | train_balanced_accuracy: 0.65522 | train_auc: 0.70707 | valid_balanced_accuracy: 0.61772 | valid_auc: 0.66516 |  0:16:25s
# epoch 140| loss: 0.62317 | train_balanced_accuracy: 0.6375  | train_auc: 0.69594 | valid_balanced_accuracy: 0.6176  | valid_auc: 0.66549 |  0:16:32s
# epoch 141| loss: 0.63032 | train_balanced_accuracy: 0.64854 | train_auc: 0.7041  | valid_balanced_accuracy: 0.62725 | valid_auc: 0.67211 |  0:16:39s
# epoch 142| loss: 0.62933 | train_balanced_accuracy: 0.64791 | train_auc: 0.70432 | valid_balanced_accuracy: 0.63003 | valid_auc: 0.66699 |  0:16:46s
# epoch 143| loss: 0.62704 | train_balanced_accuracy: 0.64106 | train_auc: 0.70216 | valid_balanced_accuracy: 0.59791 | valid_auc: 0.65335 |  0:16:53s
# epoch 144| loss: 0.63364 | train_balanced_accuracy: 0.63291 | train_auc: 0.69218 | valid_balanced_accuracy: 0.60033 | valid_auc: 0.64188 |  0:17:00s
# epoch 145| loss: 0.62423 | train_balanced_accuracy: 0.63596 | train_auc: 0.69343 | valid_balanced_accuracy: 0.632   | valid_auc: 0.67411 |  0:17:07s
# epoch 146| loss: 0.63008 | train_balanced_accuracy: 0.63931 | train_auc: 0.69247 | valid_balanced_accuracy: 0.62176 | valid_auc: 0.66476 |  0:17:14s
# epoch 147| loss: 0.62365 | train_balanced_accuracy: 0.63773 | train_auc: 0.69288 | valid_balanced_accuracy: 0.63763 | valid_auc: 0.66162 |  0:17:21s
# epoch 148| loss: 0.62969 | train_balanced_accuracy: 0.64632 | train_auc: 0.70455 | valid_balanced_accuracy: 0.6379  | valid_auc: 0.68608 |  0:17:29s
# epoch 149| loss: 0.62301 | train_balanced_accuracy: 0.65108 | train_auc: 0.70912 | valid_balanced_accuracy: 0.65317 | valid_auc: 0.69649 |  0:17:36s
# epoch 150| loss: 0.62421 | train_balanced_accuracy: 0.65719 | train_auc: 0.70664 | valid_balanced_accuracy: 0.66243 | valid_auc: 0.70744 |  0:17:43s
# epoch 151| loss: 0.63159 | train_balanced_accuracy: 0.65918 | train_auc: 0.70491 | valid_balanced_accuracy: 0.66756 | valid_auc: 0.71372 |  0:17:50s
# epoch 152| loss: 0.63144 | train_balanced_accuracy: 0.65131 | train_auc: 0.70209 | valid_balanced_accuracy: 0.66578 | valid_auc: 0.7081  |  0:17:57s
# epoch 153| loss: 0.62623 | train_balanced_accuracy: 0.62754 | train_auc: 0.69782 | valid_balanced_accuracy: 0.62257 | valid_auc: 0.68926 |  0:18:04s
# epoch 154| loss: 0.62712 | train_balanced_accuracy: 0.63927 | train_auc: 0.70339 | valid_balanced_accuracy: 0.65123 | valid_auc: 0.6993  |  0:18:11s
# epoch 155| loss: 0.63339 | train_balanced_accuracy: 0.63713 | train_auc: 0.70491 | valid_balanced_accuracy: 0.6238  | valid_auc: 0.68484 |  0:18:18s
# epoch 156| loss: 0.62421 | train_balanced_accuracy: 0.65063 | train_auc: 0.71138 | valid_balanced_accuracy: 0.63581 | valid_auc: 0.68386 |  0:18:25s
# epoch 596| loss: 0.10922 | train_balanced_accuracy: 0.97836 | train_auc: 0.99253 | valid_balanced_accuracy: 0.71442 | valid_auc: 0.73369 |  1:09:55s
# epoch 597| loss: 0.10757 | train_balanced_accuracy: 0.97844 | train_auc: 0.9929  | valid_balanced_accuracy: 0.7193  | valid_auc: 0.73195 |  1:10:02s
# epoch 598| loss: 0.08885 | train_balanced_accuracy: 0.97827 | train_auc: 0.99334 | valid_balanced_accuracy: 0.71422 | valid_auc: 0.72959 |  1:10:09s
# epoch 599| loss: 0.09677 | train_balanced_accuracy: 0.9741  | train_auc: 0.9929  | valid_balanced_accuracy: 0.70351 | valid_auc: 0.72912 |  1:10:17s
# epoch 600| loss: 0.09487 | train_balanced_accuracy: 0.97966 | train_auc: 0.99438 | valid_balanced_accuracy: 0.69808 | valid_auc: 0.74611 |  1:10:23s
# epoch 601| loss: 0.0875  | train_balanced_accuracy: 0.97876 | train_auc: 0.99391 | valid_balanced_accuracy: 0.70482 | valid_auc: 0.75502 |  1:10:30s
# epoch 602| loss: 0.08408 | train_balanced_accuracy: 0.97951 | train_auc: 0.99458 | valid_balanced_accuracy: 0.69398 | valid_auc: 0.74178 |  1:10:37s
# epoch 603| loss: 0.08248 | train_balanced_accuracy: 0.98097 | train_auc: 0.99492 | valid_balanced_accuracy: 0.6801  | valid_auc: 0.72662 |  1:10:44s
# epoch 604| loss: 0.07983 | train_balanced_accuracy: 0.98105 | train_auc: 0.9952  | valid_balanced_accuracy: 0.69491 | valid_auc: 0.73611 |  1:10:51s
# epoch 605| loss: 0.07635 | train_balanced_accuracy: 0.98097 | train_auc: 0.99538 | valid_balanced_accuracy: 0.70353 | valid_auc: 0.74529 |  1:10:58s
# epoch 606| loss: 0.08802 | train_balanced_accuracy: 0.98064 | train_auc: 0.99557 | valid_balanced_accuracy: 0.7112  | valid_auc: 0.74376 |  1:11:05s
# epoch 607| loss: 0.0877  | train_balanced_accuracy: 0.98089 | train_auc: 0.99528 | valid_balanced_accuracy: 0.70766 | valid_auc: 0.75054 |  1:11:12s
# epoch 608| loss: 0.0815  | train_balanced_accuracy: 0.98163 | train_auc: 0.99539 | valid_balanced_accuracy: 0.70167 | valid_auc: 0.73816 |  1:11:19s
# epoch 609| loss: 0.08022 | train_balanced_accuracy: 0.98252 | train_auc: 0.99583 | valid_balanced_accuracy: 0.6981  | valid_auc: 0.72691 |  1:11:25s
# epoch 610| loss: 0.07256 | train_balanced_accuracy: 0.98056 | train_auc: 0.99561 | valid_balanced_accuracy: 0.70222 | valid_auc: 0.71619 |  1:11:32s
# epoch 611| loss: 0.07829 | train_balanced_accuracy: 0.98114 | train_auc: 0.99574 | valid_balanced_accuracy: 0.69287 | valid_auc: 0.71462 |  1:11:39s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 21
#      18 save_history = []
#      20 # Fit the model
# ---> 21 clf.fit(
#      22     X_train=X_train,
#      23     y_train=y_train,
#      24     eval_set=[(X_train,y_train), (X_val, y_val)],
#      25     eval_name=['train','valid'],
#      26     max_epochs=max_epochs,
#      27     eval_metric=['balanced_accuracy', 'auc'],
#      28     loss_fn = loss_fn,
#      29     patience = 0
#      30 )
#      31 save_history.append(clf.history["valid_balanced_accuracy"])
#
# File /opt/conda/lib/python3.10/site-packages/pytorch_tabnet/abstract_model.py:258, in TabModel.fit(self, X_train, y_train, eval_set, eval_name, eval_metric, loss_fn, weights, max_epochs, patience, batch_size, virtual_batch_size, num_workers, drop_last, callbacks, pin_memory, from_unsupervised, warm_start, augmentations, compute_importance)
#     253 for epoch_idx in range(self.max_epochs):
#     254
#     255     # Call method on_epoch_begin for all callbacks
#     256     self._callback_container.on_epoch_begin(epoch_idx)
# --> 258     self._train_epoch(train_dataloader)
#     260     # Apply predict epoch to all eval sets
#     261     for eval_name, valid_dataloader in zip(eval_names, valid_dataloaders):
#
# File /opt/conda/lib/python3.10/site-packages/pytorch_tabnet/abstract_model.py:489, in TabModel._train_epoch(self, train_loader)
#     486 for batch_idx, (X, y) in enumerate(train_loader):
#     487     self._callback_container.on_batch_begin(batch_idx)
# --> 489     batch_logs = self._train_batch(X, y)
#     491     self._callback_container.on_batch_end(batch_idx, batch_logs)
#     493 epoch_logs = {"lr": self._optimizer.param_groups[-1]["lr"]}
#
# File /opt/conda/lib/python3.10/site-packages/pytorch_tabnet/abstract_model.py:534, in TabModel._train_batch(self, X, y)
#     531 loss = loss - self.lambda_sparse * M_loss
#     533 # Perform backward pass and optimization
# --> 534 loss.backward()
#     535 if self.clip_value:
#     536     clip_grad_norm_(self.network.parameters(), self.clip_value)
#
# File /opt/conda/lib/python3.10/site-packages/torch/_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File /opt/conda/lib/python3.10/site-packages/torch/autograd/__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:

# %%
import gc
import torch

# Assuming `obj` is the object consuming GPU memory
obj = None

# Collect garbage
gc.collect()

# Empty PyTorch cache
torch.cuda.empty_cache()

# %%
from pytorch_tabnet.tab_model import TabNetClassifier
max_epochs = 400

from sklearn.model_selection import train_test_split

# Splitting data into training and testing sets (70% train, 30% test)
X_train_val, X_test, y_train_val, y_test = train_test_split(tabular_data, label, test_size=0.15, random_state=42)

# Splitting training and validation sets from the remaining data (70% train, 15% validation)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.18, random_state=42)

y_train_int = y_train.astype(int)
cls_num_list = np.bincount(y_train_int)

loss_fn = nn.CrossEntropyLoss(weight=torch.tensor((num_ones, num_zeroes)).to('cuda')/1e4)

clf = TabNetClassifier(n_d=50, n_a=50, n_steps=10, n_independent=5, n_shared=5, device_name = 'cuda')
save_history = []

# Fit the model
clf.fit(
    X_train=X_train,
    y_train=y_train,
    eval_set=[(X_train,y_train), (X_val, y_val)],
    eval_name=['train','valid'],
    max_epochs=max_epochs,
    eval_metric=['balanced_accuracy', 'auc'],
    loss_fn = loss_fn,
    patience = 0
)
save_history.append(clf.history["valid_balanced_accuracy"])
# Out:
# /opt/conda/lib/python3.10/site-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cuda
#   warnings.warn(f"Device used : {self.device}")
# /opt/conda/lib/python3.10/site-packages/pytorch_tabnet/abstract_model.py:687: UserWarning: No early stopping will be performed, last training weights will be used.
#   warnings.warn(wrn_msg)
# epoch 0  | loss: 1.72685 | train_balanced_accuracy: 0.50181 | train_auc: 0.50278 | valid_balanced_accuracy: 0.49585 | valid_auc: 0.50047 |  0:00:06s
# epoch 1  | loss: 1.69148 | train_balanced_accuracy: 0.5     | train_auc: 0.57713 | valid_balanced_accuracy: 0.5     | valid_auc: 0.54518 |  0:00:13s
# epoch 161| loss: 0.63705 | train_balanced_accuracy: 0.64737 | train_auc: 0.70497 | valid_balanced_accuracy: 0.61994 | valid_auc: 0.66435 |  0:19:02s
# epoch 162| loss: 0.62475 | train_balanced_accuracy: 0.65412 | train_auc: 0.71134 | valid_balanced_accuracy: 0.61745 | valid_auc: 0.67085 |  0:19:09s
# epoch 163| loss: 0.62518 | train_balanced_accuracy: 0.65964 | train_auc: 0.71768 | valid_balanced_accuracy: 0.61818 | valid_auc: 0.66846 |  0:19:16s
# epoch 164| loss: 0.61338 | train_balanced_accuracy: 0.66248 | train_auc: 0.72272 | valid_balanced_accuracy: 0.63073 | valid_auc: 0.6767  |  0:19:23s
# epoch 165| loss: 0.62326 | train_balanced_accuracy: 0.66108 | train_auc: 0.72291 | valid_balanced_accuracy: 0.63333 | valid_auc: 0.69177 |  0:19:30s
# epoch 166| loss: 0.61482 | train_balanced_accuracy: 0.67607 | train_auc: 0.73473 | valid_balanced_accuracy: 0.65496 | valid_auc: 0.70021 |  0:19:37s
# epoch 167| loss: 0.61834 | train_balanced_accuracy: 0.66544 | train_auc: 0.73435 | valid_balanced_accuracy: 0.65518 | valid_auc: 0.70284 |  0:19:44s
# epoch 168| loss: 0.60915 | train_balanced_accuracy: 0.67592 | train_auc: 0.73669 | valid_balanced_accuracy: 0.66389 | valid_auc: 0.7036  |  0:19:51s
# epoch 169| loss: 0.60718 | train_balanced_accuracy: 0.67934 | train_auc: 0.74005 | valid_balanced_accuracy: 0.65249 | valid_auc: 0.70297 |  0:19:58s
# epoch 170| loss: 0.60662 | train_balanced_accuracy: 0.68146 | train_auc: 0.74222 | valid_balanced_accuracy: 0.66351 | valid_auc: 0.71062 |  0:20:05s
# epoch 171| loss: 0.60604 | train_balanced_accuracy: 0.67845 | train_auc: 0.73373 | valid_balanced_accuracy: 0.66867 | valid_auc: 0.7304  |  0:20:12s
# epoch 172| loss: 0.618   | train_balanced_accuracy: 0.66557 | train_auc: 0.72518 | valid_balanced_accuracy: 0.64672 | valid_auc: 0.70298 |  0:20:19s
# epoch 173| loss: 0.60887 | train_balanced_accuracy: 0.66509 | train_auc: 0.729   | valid_balanced_accuracy: 0.66555 | valid_auc: 0.72134 |  0:20:26s
# epoch 174| loss: 0.60918 | train_balanced_accuracy: 0.67127 | train_auc: 0.73496 | valid_balanced_accuracy: 0.64911 | valid_auc: 0.71811 |  0:20:33s
# epoch 175| loss: 0.59887 | train_balanced_accuracy: 0.67339 | train_auc: 0.74224 | valid_balanced_accuracy: 0.66551 | valid_auc: 0.72147 |  0:20:40s
# epoch 176| loss: 0.60364 | train_balanced_accuracy: 0.67636 | train_auc: 0.74    | valid_balanced_accuracy: 0.65988 | valid_auc: 0.72288 |  0:20:47s
# epoch 177| loss: 0.59476 | train_balanced_accuracy: 0.68204 | train_auc: 0.74803 | valid_balanced_accuracy: 0.66154 | valid_auc: 0.72392 |  0:20:54s
# epoch 178| loss: 0.59949 | train_balanced_accuracy: 0.67698 | train_auc: 0.74536 | valid_balanced_accuracy: 0.65724 | valid_auc: 0.71189 |  0:21:01s
# epoch 250| loss: 0.44941 | train_balanced_accuracy: 0.8016  | train_auc: 0.87698 | valid_balanced_accuracy: 0.72905 | valid_auc: 0.79959 |  0:29:27s
# epoch 251| loss: 0.43845 | train_balanced_accuracy: 0.80307 | train_auc: 0.87855 | valid_balanced_accuracy: 0.73624 | valid_auc: 0.80092 |  0:29:34s
# epoch 252| loss: 0.43967 | train_balanced_accuracy: 0.80809 | train_auc: 0.88219 | valid_balanced_accuracy: 0.76322 | valid_auc: 0.80828 |  0:29:41s
# epoch 253| loss: 0.44156 | train_balanced_accuracy: 0.81292 | train_auc: 0.89038 | valid_balanced_accuracy: 0.74637 | valid_auc: 0.80537 |  0:29:48s
# epoch 254| loss: 0.43082 | train_balanced_accuracy: 0.81892 | train_auc: 0.8954  | valid_balanced_accuracy: 0.74484 | valid_auc: 0.80549 |  0:29:55s
# epoch 255| loss: 0.42736 | train_balanced_accuracy: 0.79364 | train_auc: 0.88754 | valid_balanced_accuracy: 0.7168  | valid_auc: 0.78818 |  0:30:02s
# epoch 256| loss: 0.42491 | train_balanced_accuracy: 0.82612 | train_auc: 0.9014  | valid_balanced_accuracy: 0.73888 | valid_auc: 0.80594 |  0:30:09s
# epoch 257| loss: 0.40642 | train_balanced_accuracy: 0.82625 | train_auc: 0.90398 | valid_balanced_accuracy: 0.72806 | valid_auc: 0.79708 |  0:30:16s
# epoch 258| loss: 0.40667 | train_balanced_accuracy: 0.82771 | train_auc: 0.90434 | valid_balanced_accuracy: 0.73686 | valid_auc: 0.80217 |  0:30:23s

# %%
import plotly.express as px


explainability_matrix , masks = clf.explain(X_val)

exp_mat = np.sum(explainability_matrix.reshape((X_val.shape[0], num_features, embedding_size)), axis=2)

# Normalize the importance by sample
normalized_explain_mat = np.divide(exp_mat, exp_mat.sum(axis=1).reshape(-1, 1)+1e-8)

# Add prediction to better understand correlation between features and predictions
val_preds = clf.predict(X_val)

# explain_and_preds = np.hstack([normalized_explain_mat, val_preds.reshape(-1, 1)])

features = ['GENDER', 'AGE', 'RELIGION', 'ETHNICITY',
       'ADMISSION_TYPE', 'ADMISSION_LOCATION', 'DIAGNOSIS', 'PROCEDURE',
       'CATEGORY', 'DESCRIPTION', 'TEXT']

px.imshow(normalized_explain_mat,
          labels=dict(x="Features", y="Samples", color="Importance"),
#           x=features+["prediction"],
          x=features,
          title="Sample wise feature importance",
          color_continuous_scale='Jet',
          height=1000

# %%
p = clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, p)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Class 0', 'Class 1'])

fig, ax = plt.subplots(figsize=(8, 6))
disp.plot(ax=ax, cmap='Blues', xticks_rotation='horizontal')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
# plt.tight_layout()
# plt.show()
plt.savefig('cm_test.png')

# %%
print("Class-wise accuracy on test:\nSurvival\t\tMorbidity")
print('\t'.join([str(i) for i in np.array((cm[0][0], cm[1][1]))/np.sum(cm, axis=1)]))

# %%
cm = confusion_matrix(y_val, clf.predict(X_val))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Class 0', 'Class 1'])

fig, ax = plt.subplots(figsize=(8, 6))
disp.plot(ax=ax, cmap='Blues', xticks_rotation='horizontal')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
# plt.tight_layout()
# plt.show()
plt.savefig('cm_val.png')

# %%
print("Class-wise accuracy on valid:\nSurvival\t\tMorbidity")
print('\t'.join([str(i) for i in np.array((cm[0][0], cm[1][1]))/np.sum(cm, axis=1)]))

# %%
plt.plot(clf.history['train_balanced_accuracy'], label="Training")
plt.plot(clf.history['valid_balanced_accuracy'], label="Validation")
plt.grid()
plt.xlabel("Epochs")
plt.ylabel("Balanced Acc")
plt.legend()
plt.title("Balanced accuracy vs epochs")
# plt.show()
plt.savefig('bacc.png')

# %%
plt.plot(clf.history['train_auc'], label="Training")
plt.plot(clf.history['valid_auc'], label="Validation")
plt.grid()
plt.xlabel("Epochs")
plt.ylabel("AUROC")
plt.legend()
plt.title("AUROC vs epochs")
# plt.show()
plt.savefig('auroc.png')

# %%
from sklearn.metrics import balanced_accuracy_score, roc_auc_score

balanced_acc = balanced_accuracy_score(y_test, p)
auc_roc = roc_auc_score(y_test, p)

print(f"BACC: {balanced_acc}\nAUROC: {auc_roc}")

# %%
print(f"BACC: {max(clf.history['valid_balanced_accuracy'])}\nAUROC: {max(clf.history['valid_auc'])}")

# %%
# plot losses
plt.plot(clf.history['loss'])
plt.grid()
plt.xlabel("Epochs")
plt.ylabel("Weighted Cross Entropy")
plt.title("Loss vs epochs")
# plt.show()
plt.savefig('loss.png')

# %%
feat_imp = np.sum(clf.feature_importances_.reshape(num_features, embedding_size), axis=1)
columns = ['GENDER', 'AGE', 'RELIGION', 'ETHNICITY',
       'ADMISSION_TYPE', 'ADMISSION_LOCATION', 'DIAGNOSIS', 'PROCEDURE',
       'CATEGORY', 'DESCRIPTION', 'TEXT']

# %%
sorted_indices = np.argsort(feat_imp)[::-1]  # Get indices to sort in descending order
sorted_feat_imp = feat_imp[sorted_indices]
sorted_feature_names = [columns[i] for i in sorted_indices]

# Create bar plot
plt.figure(figsize=(10, 6))
plt.bar(range(len(sorted_feat_imp)), sorted_feat_imp, align='center', color='skyblue')
plt.xticks(range(len(sorted_feat_imp)), sorted_feature_names, rotation=45, ha='right', fontsize=12)
plt.xlabel('Feature', fontsize=14)
plt.ylabel('Importance', fontsize=14)
plt.title('Feature Importance', fontsize=16)
# plt.tight_layout()
# plt.show()
plt.grid()
plt.savefig('feat_imp.png')

# %%
import numpy as np
import torch
from pytorch_tabnet.tab_model import TabNetRegressor
from sklearn.model_selection import train_test_split

# Assuming embeddings and t are already NumPy arrays
# Ensure that embeddings and t have appropriate shapes and formats



los = np.array(los)
# Define max_epochs
max_epochs = 500

# Splitting data into training and testing sets (85% train, 15% test)
X_train_val, X_test, y_train_val, y_test = train_test_split(tabular_data, los, test_size=0.15, random_state=42)

# Splitting training and validation sets from the remaining data (70% train, 15% validation)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.18, random_state=42)
y_train = y_train.reshape(-1, 1)
y_val = y_val.reshape(-1, 1)


save_history = []

# Initialize TabNetRegressor
clf = TabNetRegressor(n_d=30, n_a=30, n_steps=7, n_independent=3,device_name = 'cuda')


# Fit the model
clf.fit(
    X_train=X_train,
    y_train=y_train,
    eval_set=[(X_train,y_train),(X_val,y_val)],
    eval_name=['train','valid'],
    max_epochs=max_epochs,
    eval_metric=['rmse','mae'],
    patience = 0
)
save_history.append(clf.history["valid_rmse"])

# %%
# plot losses
plt.grid(True)
plt.plot(clf.history['loss'])

# %%
# plot rmse
plt.grid(True)
plt.plot(clf.history['train_rmse'])
plt.plot(clf.history['valid_rmse'])

# %%
# plot rmse
plt.grid(True)
plt.plot(clf.history['train_mae'])
plt.plot(clf.history['valid_mae'])

# %%
# Deprecated : best model is automatically loaded at end of fit
# clf.load_best_model()

from sklearn.metrics import mean_squared_error,mean_absolute_error
preds = clf.predict(X_test)

y_true = y_test

y_preds = np.array(preds)
y_true = np.array(y_true)

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_true, y_preds))

# Calculate MAE
mae = mean_absolute_error(y_true, y_preds)

print("RMSE:", rmse)
print("MAE:", mae)

# %%
# Plot y_true against y_preds with different colors
plt.figure(figsize=(8, 6))

# Scatter plot for y_true (blue color)
plt.scatter(y_true, y_true, color='blue', label='True Values', alpha=0.5)

# Scatter plot for y_preds (green color)
plt.scatter(y_true, y_preds, color='green', label='Predicted Values', alpha=0.5)

# Plot y=x line for reference (red color)
#plt.plot([min(y_true), max(y_true)], [min(y_true), max(y_true)], color='red', label='Perfect Prediction Line')

# Customize plot elements
plt.xlabel('True Values')
plt.ylabel('Values')
plt.title('True vs. Predicted Values')
plt.grid(True)
plt.legend()  # Show legend with labels

plt.show()

# %%
clf_feat = clf.feature_importances_

# %%
x= clf_feat.reshape((embedding_size, -1))

# %%
columns = ['HADM_ID', 'SUBJECT_ID', 'GENDER', 'AGE', 'RELIGION', 'ETHNICITY',
       'ADMISSION_TYPE', 'ADMISSION_LOCATION', 'DIAGNOSIS', 'PROCEDURE',
       'CATEGORY', 'DESCRIPTION', 'TEXT', 'DISCHARGE_LOCATION']

# %%
feat_imp = np.sum(x, axis =0)
feature_names = columns.values

# %%
import numpy as np
import matplotlib.pyplot as plt



# Sort feature importance in descending order
sorted_indices = np.argsort(feat_imp)[::-1]  # Get indices to sort in descending order
sorted_feat_imp = feat_imp[sorted_indices]
sorted_feature_names = [feature_names[i] for i in sorted_indices]

# Create bar plot
plt.figure(figsize=(10, 6))
plt.bar(range(len(sorted_feat_imp)), sorted_feat_imp, align='center', color='skyblue')
plt.xticks(range(len(sorted_feat_imp)), sorted_feature_names, rotation=45, ha='right', fontsize=12)
plt.xlabel('Feature', fontsize=14)
plt.ylabel('Importance', fontsize=14)
plt.title('Feature Importance', fontsize=16)
plt.tight_layout()

# Show plot
plt.show()

# %%
from pytorch_tabnet.tab_model import TabNetRegressor
from matplotlib import pyplot as plt
import numpy as np

# Assuming X_test, clf, and masks are defined and valid

# Explanation and masks generation
explain_matrix, masks = clf.explain(X_test)

# Set the size of the plots
plt.figure(figsize=(20, 6))

# Plot each mask
for i in range(3):
    plt.subplot(1, 3, i + 1)
    plt.imshow(masks[i][:4], aspect='auto')  # Show only the first 3 rows
    plt.title(f"Mask {i}")
    plt.colorbar()  # Add color bar for reference

plt.tight_layout()  # Adjust subplot parameters to give specified padding
plt.show()
